# %%
# name = "Ahmed"
# print("Hello", name, "Welcome to Python!")



# first_name = "Japheth"
# middle_name = "O."
# last_name = "Jerry"
# print("My Full Name is:", first_name + " " + middle_name + " " + last_name)




# scores = [50, 20, 30, 70, 80, 33]
# scores.append(21)
# print(scores)

# # total = scores[0] + scores[1] + scores[2] + scores[3] + scores[4]

# total = sum(scores)
# print(total)



# Not exactly, but they're very similar!
# In Python, a dictionary is a collection of key-value pairs where each key is unique.
# JSON (JavaScript Object Notation) is a data format used to store and transmit data.
# A JSON object looks very much like a Python dictionary: both use curly braces, and both use key-value pairs.

# profile = {
#     "first_name": "Ahmed",
#     "last_name": "Hassan",
#     "age": 20,
#     "profession": "Engineer"
# }

# profile["hobby"] = "Reading"

# profile["age"] = 21

# print(profile)
# print("profile's first name is:", profile["first_name"])
# print("profile's last name is:", profile["last_name"])




# A controll structure that executes a particular statement repeatedly untill a specific objective is being acheived is called a loop.
# A loop is a programming construct that repeats a block of code multiple times.
# In Python, there are mainly two types of loops: 'for' loops and 'while' loops.

# Example of a 'for' loop:
# numbers = [2, 4, 5, 1, 3]
# for i in numbers:
#     print("The number is:", i)



# Example of a 'while' loop:
# count = 0
# while count < 3:
#     print("Count is:", count)
#     count += 1

i = 1

while i < 20:
    print(i)
    i += 1
